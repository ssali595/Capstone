# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hwc.csv')
df.head()
df.shape
# Out:
# (5599, 118)

# %%
df.head()
# Out:
#                   P_NAME   P_DETECTION P_DISCOVERY_FACILITY  P_YEAR  \
# 0  OGLE-2016-BLG-1227L b  Microlensing                 OGLE    2020
# 1           Kepler-276 c       Transit               Kepler    2013
# 2           Kepler-829 b       Transit               Kepler    2016
# 3               K2-283 b       Transit                   K2    2018
# 4           Kepler-477 b       Transit               Kepler    2016
#
#      P_UPDATE  P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  P_MASS_LIMIT  \
# 0  2020-04-02  250.00            -120.0             413.0             0
# 1  2018-09-25   16.60              -3.6               4.4             0
# 2  2019-04-16    5.10               NaN               NaN             0
# 3  2019-09-05   12.20               NaN               NaN             0
# 4  2019-04-16    4.94               NaN               NaN             0
#
#       P_MASS_ORIGIN  ...  S_ABIO_ZONE  S_TIDAL_LOCK  P_HABZONE_OPT  \
# ...

# %%
##Lots of extra data in here I don't need. Let's try a different dataset.

# %%
h_df = pd.read_csv('hwc_table_all.csv')
h_df.head()
# Out:
#         Name                Type Detection Method  Mass<br>(M<sub>E</sub>)  \
# 0  TOI-904 c  M Warm Superterran          Transit                    5.340
# 1  TOI-700 e       M Warm Terran          Transit                    0.818
# 2  TOI-700 d       M Warm Terran          Transit                    1.250
# 3   GJ 357 d  M Warm Superterran  Radial Velocity                    6.100
# 4  GJ 3293 d  M Warm Superterran  Radial Velocity                    7.600
#
#    Radius<br>(R<sub>E</sub>)  Flux<br>(S<sub>E</sub>)  \
# 0                      2.167                 0.524434
# 1                      0.953                 1.278049
# 2                      1.073                 0.859827
# 3                      2.340                 0.382595
# 4                      2.670                 0.588593
#
#    <i>T<sub>surf</sub></i><br>(K)  Period<br>(days)  Distance<br>(ly)  \
# 0                      244.820750          83.99970        150.322365
# ...

# %%
##This is much more relevant, lets get a shape.

# %%
h_df.shape
# Out:
# (70, 11)

# %%
#Descriptive Statistics
print("\nDescriptive Statistics:")
print(df.describe())

#Data Types and Missing Values
print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())

#Visualize Distributions
# Plot histograms for numerical columns
df.hist(figsize=(15, 10))
plt.suptitle('Histograms of Numerical Columns')
plt.show()
# Out:
# Descriptive Statistics:
#             P_YEAR        P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# count  5599.000000   5592.000000       2506.000000       2506.000000
# mean   2016.188962    442.521283       -127.777520        174.465166
# std       4.527714   2369.505048        383.670428        625.151645
# min    1992.000000      0.020000      -6038.739700          0.000000
# 25%    2014.000000      4.040000        -73.100900          2.712500
# 50%    2016.000000      8.750000        -19.069800         20.000000
# 75%    2020.000000    162.092490         -2.542630         85.813670
# max    2024.000000  89700.000000          0.000000      12395.308000
#
#        P_MASS_LIMIT     P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  \
# count   5599.000000  5592.000000         3847.000000         3847.000000
# mean       0.022861     5.715494           -0.432279            0.544259
# std        0.160982     5.331450            0.960669            1.568228
# ...

# %%
# Filter only numeric columns for correlation matrix
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
corr_matrix = numeric_df.corr()

# Print the correlation matrix
print("\nCorrelation Matrix:")
print(corr_matrix)

# Plot heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#                     P_YEAR    P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# P_YEAR            1.000000 -0.020359         -0.014786          0.037491
# P_MASS           -0.020359  1.000000         -0.686321          0.615186
# P_MASS_ERROR_MIN -0.014786 -0.686321          1.000000         -0.852940
# P_MASS_ERROR_MAX  0.037491  0.615186         -0.852940          1.000000
# P_MASS_LIMIT      0.009022  0.004388          0.007754         -0.002474
# ...                    ...       ...               ...               ...
# S_TIDAL_LOCK     -0.122054 -0.008232          0.063114         -0.087800
# P_HABZONE_OPT    -0.109231  0.023193          0.041432         -0.023414
# P_HABZONE_CON    -0.112899  0.029389          0.027686         -0.008856
# P_HABITABLE       0.021590 -0.019812          0.037414         -0.031406
# P_ESI             0.088928 -0.154341          0.168532         -0.128554
#
#                   P_MASS_LIMIT  P_RADIUS  P_RADIUS_ERROR_MIN  \
# ...

# %%
##This isn't super understandable, so let me try with the previous data set

# %%
h_df.hist(figsize=(15, 10))
plt.suptitle('Histograms of Numerical Columns')
plt.show()

# Plot boxplots for numerical columns
h_df.plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), title='Boxplots of Numerical Columns')
plt.suptitle('Boxplots of Numerical Columns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       3 plt.show()
#       5 # Plot boxplots for numerical columns
# ----> 6 h_df.plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), title='Boxplots of Numerical Columns')
#       7 plt.suptitle('Boxplots of Numerical Columns')
#       8 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
# Plot boxplots for numerical columns
h_df.plot(kind='box', subplots=True, layout=(4, 6), figsize=(15, 10), title='Boxplots of Numerical Columns')
plt.suptitle('Boxplots of Numerical Columns')
plt.show()

# %%
# Step 6: Relationships Between Variables
# Filter only numeric columns for correlation matrix
numeric_df = df.select_dtypes(include=['number'])

# Convert columns to numeric where possible, ignoring errors
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Calculate the correlation matrix
corr_matrix = numeric_df.corr()

# Print the correlation matrix
print("\nCorrelation Matrix:")
print(corr_matrix)
# Out:
# Correlation Matrix:
#                     P_YEAR    P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# P_YEAR            1.000000 -0.020359         -0.014786          0.037491
# P_MASS           -0.020359  1.000000         -0.686321          0.615186
# P_MASS_ERROR_MIN -0.014786 -0.686321          1.000000         -0.852940
# P_MASS_ERROR_MAX  0.037491  0.615186         -0.852940          1.000000
# P_MASS_LIMIT      0.009022  0.004388          0.007754         -0.002474
# ...                    ...       ...               ...               ...
# S_TIDAL_LOCK     -0.122054 -0.008232          0.063114         -0.087800
# P_HABZONE_OPT    -0.109231  0.023193          0.041432         -0.023414
# P_HABZONE_CON    -0.112899  0.029389          0.027686         -0.008856
# P_HABITABLE       0.021590 -0.019812          0.037414         -0.031406
# P_ESI             0.088928 -0.154341          0.168532         -0.128554
#
#                   P_MASS_LIMIT  P_RADIUS  P_RADIUS_ERROR_MIN  \
# ...

# %%
numeric_h_df = h_df.select_dtypes(include=['number'])

# Convert columns to numeric where possible, ignoring errors
for col in h_df.columns:
    h_df[col] = pd.to_numeric(h_df[col], errors='coerce')

# Calculate the correlation matrix
corr_matrix_h = numeric_h_df.corr()

# Print the correlation matrix
print("\nCorrelation Matrix:")
print(corr_matrix_h)
# Out:
# Correlation Matrix:
#                                 Name  Type  Detection Method  \
# Name                             NaN   NaN               NaN
# Type                             NaN   NaN               NaN
# Detection Method                 NaN   NaN               NaN
# Mass<br>(M<sub>E</sub>)          NaN   NaN               NaN
# Radius<br>(R<sub>E</sub>)        NaN   NaN               NaN
# Flux<br>(S<sub>E</sub>)          NaN   NaN               NaN
# <i>T<sub>surf</sub></i><br>(K)   NaN   NaN               NaN
# Period<br>(days)                 NaN   NaN               NaN
# Distance<br>(ly)                 NaN   NaN               NaN
# Age<br>(Gy)                      NaN   NaN               NaN
# ESI                              NaN   NaN               NaN
#
#                                 Mass<br>(M<sub>E</sub>)  \
# Name                                                NaN
# Type                                                NaN
# ...

# %%
plt.figure(figsize=(5, 4))
sns.heatmap(corr_matrix_h, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap')
plt.show()›Í
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# Pairplot for relationships
sns.pairplot(numeric_h_df)
plt.suptitle('Pairplot of the Dataset', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Scatterplot matrix for a detailed look
pd.plotting.scatter_matrix(numeric_h_df, figsize=(15, 10))
plt.suptitle('Scatter Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Scatterplot matrix for a detailed look
# ----> 2 pd.plotting.scatter_matrix(numeric_h_df, figsize=(15, 10))
#       3 plt.suptitle('Scatter Matrix')
#       4 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_misc.py:220, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     168 """
#     169 Draw a matrix of scatter plots.
#     170
#    (...)
#     217           dtype=object)
#     218 """
#     219 plot_backend = _get_plot_backend("matplotlib")
# --> 220 return plot_backend.scatter_matrix(
#     221     frame=frame,
#     222     alpha=alpha,
#     223     figsize=figsize,
#     224     ax=ax,
#     225     grid=grid,
#     226     diagonal=diagonal,
#     227     marker=marker,
# ...

# %%
›
